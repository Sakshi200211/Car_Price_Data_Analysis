# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings 
warnings.filterwarnings("ignore")

# %%
car = pd.read_csv("car_data.csv")

# %%
car
# Out:
#                         Model  Selling Price  Kilometers Driven  Year  \
# 0          MarutiWagonR1.0LXI         312165              82238  2014
# 1             ToyotaEtiosLiva         313799              30558  2013
# 2               MarutiAlto800         295999              22164  2018
# 3                 MarutiSwift         435199              30535  2013
# 4             MarutiWagonR1.0         289099              15738  2013
# ...                       ...            ...                ...   ...
# 2232          MarutiWagonR1.0         385999              45263  2015
# 2233              MarutiSwift         324099             100335  2012
# 2234              HyundaiEonD         212299              28016  2011
# 2235  FordEcosport1.5AMBIENTE         378899              87947  2013
# 2236            MarutiAltoK10         304299              33639  2015
#
#              Owner     Fuel Type Transmission   Insurance  Car Condition
# ...

# %%
car.insert(0, 'Sr_no', range(1, len(car) + 1))

# %%
car
# Out:
#       Sr_no                    Model  Selling Price  Kilometers Driven  Year  \
# 0         1       MarutiWagonR1.0LXI         312165              82238  2014
# 1         2          ToyotaEtiosLiva         313799              30558  2013
# 2         3            MarutiAlto800         295999              22164  2018
# 3         4              MarutiSwift         435199              30535  2013
# 4         5          MarutiWagonR1.0         289099              15738  2013
# ...     ...                      ...            ...                ...   ...
# 2232   2233          MarutiWagonR1.0         385999              45263  2015
# 2233   2234              MarutiSwift         324099             100335  2012
# 2234   2235              HyundaiEonD         212299              28016  2011
# 2235   2236  FordEcosport1.5AMBIENTE         378899              87947  2013
# 2236   2237            MarutiAltoK10         304299              33639  2015
#
# ...

# %%
len(car)
# Out:
# 2237

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2237 entries, 0 to 2236
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sr_no              2237 non-null   int64
#  1   Model              2237 non-null   object
#  2   Selling Price      2237 non-null   int64
#  3   Kilometers Driven  2237 non-null   int64
#  4   Year               2237 non-null   int64
#  5   Owner              2237 non-null   object
#  6   Fuel Type          2237 non-null   object
#  7   Transmission       2237 non-null   object
#  8   Insurance          2223 non-null   object
#  9   Car Condition      2237 non-null   float64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 174.9+ KB

# %%
car.describe()
# Out:
#              Sr_no  Selling Price  Kilometers Driven         Year  \
# count  2237.000000   2.237000e+03        2237.000000  2237.000000
# mean   1119.000000   4.184431e+05       61928.605275  2013.763523
# std     645.910598   2.280516e+05       42260.955917     2.874686
# min       1.000000   7.529900e+04         913.000000  2006.000000
# 25%     560.000000   2.720990e+05       32137.000000  2012.000000
# 50%    1119.000000   3.557990e+05       55430.000000  2014.000000
# 75%    1678.000000   5.032990e+05       83427.000000  2016.000000
# max    2237.000000   1.952397e+06      855881.000000  2020.000000
#
#        Car Condition
# count    2237.000000
# mean        4.370854
# std         0.288990
# min         3.000000
# 25%         4.200000
# 50%         4.300000
# 75%         4.600000
# max         5.000000

# %%
car["Selling Price"].quantile(0.1)
# Out:
# np.float64(204999.0)

# %%
car.iloc[25]
# Out:
# Sr_no                           26
# Model                MarutiAltoK10
# Selling Price               309999
# Kilometers Driven            36245
# Year                          2017
# Owner                  First Owner
# Fuel Type                   Petrol
# Transmission                MANUAL
# Insurance               23-09-2021
# Car Condition                  4.7
# Name: 25, dtype: object

# %%
car.iloc[21:31]
# Out:
#     Sr_no                  Model  Selling Price  Kilometers Driven  Year  \
# 21     22         MahindraTUV300         656399              34658  2016
# 22     23      HondaAmaze1.5VCVT         698899              53486  2018
# 23     24             TataNanoXT         100599              35905  2014
# 24     25            RenaultKwid         250399              39278  2016
# 25     26          MarutiAltoK10         309999              36245  2017
# 26     27  HyundaiElitei20SPORTZ         518099              61923  2015
# 27     28        MarutiZenEstilo         211799              39612  2010
# 28     29       MarutiCelerioZXI         332627              58558  2015
# 29     30  MarutiSwiftDzireVDIBS         477214              72553  2013
# 30     31   MarutiBalenoALPHA1.2         669899              13931  2018
#
#            Owner Fuel Type Transmission    Insurance  Car Condition
# 21   First Owner    Diesel       MANUAL   02-07-2021            4.5
# ...

# %%
car[car["Insurance"]=="Expired"]
# Out:
#       Sr_no                          Model  Selling Price  Kilometers Driven  \
# 0         1             MarutiWagonR1.0LXI         312165              82238
# 6         7  HyundaiGrandi10SPORTZ1.2KAPPA         410788              32496
# 12       13                 HondaCivic1.8S         146870              52138
# 26       27          HyundaiElitei20SPORTZ         518099              61923
# 29       30          MarutiSwiftDzireVDIBS         477214              72553
# ...     ...                            ...            ...                ...
# 2213   2214                    MarutiEeco7         360599              54919
# 2214   2215          HyundaiElitei20SPORTZ         520399              52042
# 2227   2228             ToyotaCorollaAltis         241899              83273
# 2228   2229         MarutiCiazDELTA1.5SHVS         819210              38480
# 2234   2235                    HyundaiEonD         212299              28016
#
# ...

# %%
car[car["Selling Price"]>20000]
# Out:
#       Sr_no                    Model  Selling Price  Kilometers Driven  Year  \
# 0         1       MarutiWagonR1.0LXI         312165              82238  2014
# 1         2          ToyotaEtiosLiva         313799              30558  2013
# 2         3            MarutiAlto800         295999              22164  2018
# 3         4              MarutiSwift         435199              30535  2013
# 4         5          MarutiWagonR1.0         289099              15738  2013
# ...     ...                      ...            ...                ...   ...
# 2232   2233          MarutiWagonR1.0         385999              45263  2015
# 2233   2234              MarutiSwift         324099             100335  2012
# 2234   2235              HyundaiEonD         212299              28016  2011
# 2235   2236  FordEcosport1.5AMBIENTE         378899              87947  2013
# 2236   2237            MarutiAltoK10         304299              33639  2015
#
# ...

# %%
car[(car["Selling Price"]>20000)&(car["Model"]=="MarutiSwift")]
# Out:
#       Sr_no        Model  Selling Price  Kilometers Driven  Year  \
# 3         4  MarutiSwift         435199              30535  2013
# 41       42  MarutiSwift         260699             141644  2012
# 45       46  MarutiSwift         341399              61365  2012
# 47       48  MarutiSwift         292399              96637  2012
# 76       77  MarutiSwift         315999             164127  2012
# ...     ...          ...            ...                ...   ...
# 2171   2172  MarutiSwift         364799              79019  2013
# 2182   2183  MarutiSwift         597799              50244  2018
# 2190   2191  MarutiSwift         403099              54695  2014
# 2210   2211  MarutiSwift         365699             104448  2014
# 2233   2234  MarutiSwift         324099             100335  2012
#
#              Owner     Fuel Type Transmission   Insurance  Car Condition
# 3      First Owner        Diesel       MANUAL        Comp            4.3
# ...

# %%
car["Model"].value_counts()
# Out:
# Model
# MarutiSwift                     118
# MarutiAltoK10                    83
# MarutiWagonR1.0                  80
# MarutiAlto800                    63
# MarutiSwiftDzireVDIBS            52
#                                ...
# ToyotaYARISJ                      1
# MarutiErtigaZDIPLUS               1
# FordFigoAspire1.5TREND            1
# HyundaiGRANDI10NIOSSPORTZ1.2      1
# HondaCivic1.8S                    1
# Name: count, Length: 434, dtype: int64

# %%
car.groupby("Model")["Selling Price"].mean().sort_values()
# Out:
# Model
# HyundaiSantroXingXLERLXEURO    8.979400e+04
# TataNanoXT                     1.057657e+05
# ChevroletSparkLS               1.105990e+05
# ToyotaCorollaH21.8             1.189990e+05
# MarutiSwiftVXI1.3              1.195990e+05
#                                    ...
# AudiQ335TDI                    1.652949e+06
# MercedesBenzGLAClass200CDI     1.654999e+06
# MGHECTORSHARPDCT               1.708199e+06
# ToyotaInnovaCrysta2.4VX7       1.817180e+06
# ToyotaInnovaCrysta2.8ZXAT7     1.952397e+06
# Name: Selling Price, Length: 434, dtype: float64

# %%
plt.figure(figsize=(12,4))
plt.plot(car["Selling Price"] ,color="skyblue")

# %%
plt.figure(figsize=(12,5))
plt.scatter(car["Selling Price"],car["Car Condition"], marker="*" )
plt.xlabel("Selling Price")
plt.ylabel("Car Condition")
plt.title("Car Price analysis based on condition")
plt.colorbar()
plt.grid()
plt.show()

# %%
car.head()
# Out:
#    Sr_no               Model  Selling Price  Kilometers Driven  Year  \
# 0      1  MarutiWagonR1.0LXI         312165              82238  2014
# 1      2     ToyotaEtiosLiva         313799              30558  2013
# 2      3       MarutiAlto800         295999              22164  2018
# 3      4         MarutiSwift         435199              30535  2013
# 4      5     MarutiWagonR1.0         289099              15738  2013
#
#          Owner     Fuel Type Transmission   Insurance  Car Condition
# 0  First Owner  Petrol + CNG       MANUAL     Expired            4.2
# 1  First Owner        Petrol       MANUAL  12-09-2021            4.4
# 2  First Owner        Petrol       MANUAL  01-12-2020            4.8
# 3  First Owner        Diesel       MANUAL        Comp            4.3
# 4  First Owner        Petrol       MANUAL  11-08-2021            4.3

# %%
model_fuel_type=car.groupby("Fuel Type")["Selling Price"].sum().reset_index()

# %%
model_fuel_type
# Out:
#       Fuel Type  Selling Price
# 0        Diesel      371256028
# 1        Petrol      511038356
# 2  Petrol + CNG       51955570
# 3  Petrol + LPG        1807191

# %%
plt.figure(figsize=(12,5))
sns.barplot(model_fuel_type,x="Fuel Type",y="Selling Price" ,palette="rocket")
plt.title("Fuel type by Model")
# plt.xticks(range(0,700,215))
plt.show()

# %%
plt.figure(figsize=(12,5))
car.groupby("Model")["Car Condition"].value_counts().plot.barh(xlabel="Car Condition")
plt.grid(axis="x")
plt.yticks(range(1,1500,100))
plt.xticks(range(0,15,1))
plt.show()

# %%
plt.figure(figsize=(10,3))
plt.boxplot(car["Selling Price" ],vert=False ,meanline=True ,notch=True)
plt.xlabel("Selling Price")
plt.show()

# %%
car.reset_index(drop=True,inplace=True)

# %%
car
# Out:
#       Sr_no                    Model  Selling Price  Kilometers Driven  Year  \
# 0         1       MarutiWagonR1.0LXI         312165              82238  2014
# 1         2          ToyotaEtiosLiva         313799              30558  2013
# 2         3            MarutiAlto800         295999              22164  2018
# 3         4              MarutiSwift         435199              30535  2013
# 4         5          MarutiWagonR1.0         289099              15738  2013
# ...     ...                      ...            ...                ...   ...
# 2232   2233          MarutiWagonR1.0         385999              45263  2015
# 2233   2234              MarutiSwift         324099             100335  2012
# 2234   2235              HyundaiEonD         212299              28016  2011
# 2235   2236  FordEcosport1.5AMBIENTE         378899              87947  2013
# 2236   2237            MarutiAltoK10         304299              33639  2015
#
# ...

# %%
plt.figure(figsize=(10,4))
sns.lineplot(car["Selling Price"])
plt.title("Total Selling price Analysis")
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.lineplot(car,x="Sr_no",y="Selling Price" ,hue="Owner")
plt.title("Total Selling price Analysis")
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.countplot(car, x='Fuel Type' ,hue='Owner',palette="mako")
plt.title("Count of models by Fuel type and owner ")
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(car, x="Selling Price"  ,y="Year" ,hue="Car Condition" ,palette="rocket")

plt.show()

# %%
plt.figure(figsize=(10,4))
sns.kdeplot(car,x="Selling Price",fill=True,hue="Fuel Type" ,palette="mako")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.histplot(car,x="Fuel Type" ,hue="Owner")
plt.show()

# %%
sns.jointplot(car,x="Selling Price" ,y="Year" ,height=4,kind="hex")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.violinplot(car,x="Kilometers Driven" ,y="Owner" ,palette="rocket",fill=False )
plt.xticks(range(0,1000000,100000))
plt.title("Kilometers Driven by Owner analysis")
plt.grid()
plt.show()
